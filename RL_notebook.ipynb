# %% [markdown]
# #  TASK 3
# ## Re-inforcement Learning Notebook
# ### Bhavesh Kumar [16203173], Jeet Banerjeee [17200844]

# %% [markdown]
# ### Import packages etc

# %%
from __future__ import division
import argparse

from PIL import Image
import numpy as np
import gym
import random
import io
import sys
import csv

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Convolution2D, Permute, Conv2D
from keras.optimizers import Adam
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

from IPython.display import Image
from IPython.core.display import HTML, display
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load LunarLander-v2 environment from gym and define the network architecture

# %% [markdown]
# Define the model architecture

# %%
# define name of agent environment to use
env_name = 'LunarLander-v2'
# Load the enviroment from openai.gym that contains the state-vector representation of Lunar lander game
env = gym.make(env_name)

sd = 555
np.random.seed(sd)
random.seed(sd)
env.seed(sd)

# get the number of actions available in the environment
nb_actions = env.action_space.n

# neural netwok model
model = Sequential()
model.add(Flatten(input_shape=(1,) + env.observation_space.shape)) #Input unit layer
model.add(Dense(512)) # Layer 1 with 512 units
model.add(Activation('relu'))
model.add(Dense(256))  # Layer 2 with 256 units
model.add(Activation('relu'))
model.add(Dense(128))  # Layer 3 with 128 units
model.add(Activation('relu'))
model.add(Dense(nb_actions)) #Output unit layer
model.add(Activation('linear'))
print(model.summary())
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4608
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 516
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 169,348
# Trainable params: 169,348
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Define policy and logger callbacks and compile the model

# %%
# using Epsilon Greedy Policy, Adam as optimizer and mean absolute error (mae) to measure the performance
memory = SequentialMemory(limit=300000, window_length=1)
# Define the policy
policy = EpsGreedyQPolicy()

# Define the DQN Agent and load the model in it
# Set target_model_update to 1e-2 since we will keep learning rate to be small
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy, memory=memory, 
               nb_steps_warmup=50000, target_model_update=1e-2)


# compile the model
# Learning rate is kept small: 1e-5
dqn.compile(Adam(lr=1e-5), metrics=['mae'])

# define file names for weights and log during training
weights_filename = 'dqn_' + env_name + '_weights.h5f'
checkpoint_weights_filename = 'dqn_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]

# %% [markdown]
# ### Train the model and save weights in .h5f file

# %%
# start training the model for ~1.5 million steps, and add callbacks to generate logs
dqn.fit(env, nb_steps=1550000, log_interval=10000, visualize=False, callbacks=callbacks)

# After training is done, we save the final weights.
dqn.save_weights(weights_filename, overwrite=True)

#We have trained the model in Google Cloud instance and we are directly using the saved trained weights here.
#Hence the training logs are not shown.

# %% [markdown]
# ### Training steps versus Reward plot

# %% [markdown]
# After running different Reinforcment learning model architectures on Google Cloud instance, we observe the below graphs.

# %% [markdown]
# Hidden layers = (512,256,128), learning rate=1e-5 | Hidden layers = (128,64,64), learning rate=5e-4
# :---:|:---:
# ![Figure 1](https://image.ibb.co/jaWcmx/512_training_line.png) | ![Figure 2](https://image.ibb.co/bFfvOc/128_training_line.png)
# Model architecture 1|Model architecture 2

# %% [markdown]
# Figure 1 and Figure 2 above shows how the re-inforcement learning model learns over the training steps and the impact of learning rate on it.
#
# We have tried a couple of model architectures.
#
# In model 1, Rewards have been collected during the training steps of our final model which has 3 hidden layers and learning rate 1e-5. Model 1 started with very low reward (>-2500) as compared to model 2(~-600). Model 1 started getting positive reward after 1.1 millions steps whereas model 2 started after just 0.85 millions steps.
#
# Learning rate directly refects here in a way that smaller the learning rate more steps it takes to learn. In later steps Model 1 is quite stable in getting positive reward as compared to the 2nd model.
#
# <br><br>
# Hence, we select the 1st model with (512, 256, 128 units in hidden layers, and 1e-5 learning rate) for our further anaylsis and evaluation.

# %% [markdown]
# ### :: NOTE :: Detailed Comparison of three Reinforcement learning model architectures has been provided in the notebook named "*Analysis and Experimentation*"

# %% [markdown]
# ### Test the model using trained weights for 200 episodes

# %%
# Redirect stdout to capture test results
old_stdout = sys.stdout
sys.stdout = mystdout = io.StringIO()

# use trained weights to test the agent
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=200, visualize=False)
# Out:
# results
# Testing for 200 episodes ...
# Episode 1: reward: 199.971, steps: 326
# Episode 2: reward: 222.437, steps: 262
# Episode 3: reward: 222.270, steps: 320
# Episode 4: reward: 245.405, steps: 299
# Episode 5: reward: 33.904, steps: 1000
# Episode 6: reward: 127.211, steps: 418
# Episode 7: reward: 190.297, steps: 320
# Episode 8: reward: 241.606, steps: 280
# Episode 9: reward: 194.045, steps: 331
# Episode 10: reward: 204.806, steps: 280
# Episode 11: reward: 237.855, steps: 321
# Episode 12: reward: 181.652, steps: 375
# Episode 13: reward: 180.868, steps: 352
# Episode 14: reward: 226.004, steps: 326
# Episode 15: reward: 203.962, steps: 309
# Episode 16: reward: 193.632, steps: 341
# Episode 17: reward: 219.200, steps: 324
# Episode 18: reward: 170.339, steps: 296
# Episode 19: reward: 138.305, steps: 464
# Episode 20: reward: 236.445, steps: 281
# Episode 21: reward: 238.679, steps: 333
# Episode 22: reward: 146.331, steps: 383
# Episode 23: reward: 233.027, steps: 318
# Episode 24: reward: 234.126, steps: 306
# Episode 25: reward: 181.309, steps: 335
# Episode 26: reward: 172.322, steps: 308
# Episode 27: reward: 238.372, steps: 271
# Episode 28: reward: 225.940, steps: 355
# Episode 29: reward: 186.627, steps: 274
# Episode 30: reward: 190.323, steps: 373
# Episode 31: reward: 121.700, steps: 368
# Episode 32: reward: 170.931, steps: 329
# Episode 33: reward: 236.337, steps: 293
# Episode 34: reward: 191.066, steps: 269
# Episode 35: reward: 180.702, steps: 298
# Episode 36: reward: 203.158, steps: 321
# Episode 37: reward: 224.065, steps: 297
# Episode 38: reward: 223.421, steps: 271
# Episode 39: reward: 73.037, steps: 1000
# Episode 40: reward: 194.308, steps: 318
# Episode 41: reward: 183.942, steps: 287
# Episode 42: reward: 241.257, steps: 286
# Episode 43: reward: 240.125, steps: 284
# Episode 44: reward: 61.234, steps: 1000
# Episode 45: reward: 195.110, steps: 351
# Episode 46: reward: 260.424, steps: 251
# Episode 47: reward: 206.590, steps: 323
# Episode 48: reward: 220.820, steps: 376
# Episode 49: reward: 238.618, steps: 346
# Episode 50: reward: 204.005, steps: 284
# Episode 51: reward: 220.326, steps: 297
# Episode 52: reward: 220.564, steps: 352
# Episode 53: reward: 195.239, steps: 322
# Episode 54: reward: 208.598, steps: 292
# Episode 55: reward: 244.010, steps: 294
# Episode 56: reward: 218.251, steps: 354
# Episode 57: reward: 234.109, steps: 298
# Episode 58: reward: 219.658, steps: 298
# Episode 59: reward: 227.249, steps: 282
# Episode 60: reward: 224.236, steps: 335
# Episode 61: reward: 258.633, steps: 248
# Episode 62: reward: 238.378, steps: 297
# Episode 63: reward: 169.841, steps: 408
# Episode 64: reward: 218.091, steps: 305
# Episode 65: reward: 231.323, steps: 321
# Episode 66: reward: 229.500, steps: 330
# Episode 67: reward: 228.317, steps: 330
# Episode 68: reward: 60.614, steps: 1000
# Episode 69: reward: 180.037, steps: 362
# Episode 70: reward: 205.661, steps: 313
# Episode 71: reward: 187.416, steps: 316
# Episode 72: reward: 183.613, steps: 283
# Episode 73: reward: 210.721, steps: 310
# Episode 74: reward: 204.867, steps: 338
# Episode 75: reward: 170.455, steps: 352
# Episode 76: reward: 217.084, steps: 293
# Episode 77: reward: 211.158, steps: 284
# Episode 78: reward: 153.314, steps: 318
# Episode 79: reward: 234.777, steps: 323
# Episode 80: reward: 210.022, steps: 297
# Episode 81: reward: 238.519, steps: 297
# Episode 82: reward: 176.573, steps: 341
# Episode 83: reward: 232.712, steps: 303
# Episode 84: reward: 201.120, steps: 337
# Episode 85: reward: 186.037, steps: 334
# Episode 86: reward: 180.895, steps: 291
# Episode 87: reward: 194.254, steps: 332
# Episode 88: reward: 188.618, steps: 306
# Episode 89: reward: 221.735, steps: 319
# Episode 90: reward: 179.872, steps: 413
# Episode 91: reward: 239.518, steps: 290
# Episode 92: reward: 215.593, steps: 322
# Episode 93: reward: 209.493, steps: 348
# Episode 94: reward: 212.355, steps: 304
# Episode 95: reward: 211.320, steps: 287
# Episode 96: reward: 154.645, steps: 377
# Episode 97: reward: 228.861, steps: 306
# Episode 98: reward: -84.965, steps: 249
# Episode 99: reward: 181.534, steps: 386
# Episode 100: reward: 212.264, steps: 292
# Episode 101: reward: 195.165, steps: 266
# Episode 102: reward: 145.209, steps: 405
# Episode 103: reward: 188.498, steps: 298
# Episode 104: reward: 220.444, steps: 301
# Episode 105: reward: 225.663, steps: 287
# Episode 106: reward: 221.144, steps: 301
# Episode 107: reward: 67.406, steps: 1000
# Episode 108: reward: 236.691, steps: 327
# Episode 109: reward: 199.123, steps: 293
# Episode 110: reward: 143.368, steps: 436
# Episode 111: reward: 190.786, steps: 400
# Episode 112: reward: 177.477, steps: 289
# Episode 113: reward: 231.534, steps: 328
# Episode 114: reward: 160.175, steps: 472
# Episode 115: reward: 231.986, steps: 345
# Episode 116: reward: 201.852, steps: 271
# Episode 117: reward: 194.116, steps: 371
# Episode 118: reward: 206.401, steps: 324
# Episode 119: reward: 187.301, steps: 283
# Episode 120: reward: 153.505, steps: 569
# Episode 121: reward: 187.179, steps: 353
# Episode 122: reward: 200.183, steps: 371
# Episode 123: reward: 185.241, steps: 372
# Episode 124: reward: 191.926, steps: 308
# Episode 125: reward: 194.730, steps: 303
# Episode 126: reward: 227.294, steps: 291
# Episode 127: reward: 194.264, steps: 303
# Episode 128: reward: 188.498, steps: 276
# Episode 129: reward: 233.377, steps: 307
# Episode 130: reward: 168.810, steps: 584
# Episode 131: reward: 241.671, steps: 337
# Episode 132: reward: 194.438, steps: 278
# Episode 133: reward: 235.479, steps: 314
# Episode 134: reward: 242.803, steps: 323
# Episode 135: reward: 153.550, steps: 497
# Episode 136: reward: 234.192, steps: 304
# Episode 137: reward: 224.534, steps: 306
# Episode 138: reward: 131.476, steps: 433
# Episode 139: reward: 227.387, steps: 312
# Episode 140: reward: 206.245, steps: 317
# Episode 141: reward: 175.087, steps: 304
# Episode 142: reward: 58.577, steps: 1000
# Episode 143: reward: 186.673, steps: 386
# Episode 144: reward: 222.055, steps: 344
# Episode 145: reward: 233.687, steps: 290
# Episode 146: reward: 153.628, steps: 442
# Episode 147: reward: 200.247, steps: 397
# Episode 148: reward: 177.561, steps: 393
# Episode 149: reward: 193.504, steps: 286
# Episode 150: reward: 200.802, steps: 306
# Episode 151: reward: 236.403, steps: 316
# Episode 152: reward: 186.264, steps: 295
# Episode 153: reward: 117.859, steps: 1000
# Episode 154: reward: 194.526, steps: 303
# Episode 155: reward: 218.848, steps: 293
# Episode 156: reward: 181.622, steps: 318
# Episode 157: reward: 228.830, steps: 291
# Episode 158: reward: 226.969, steps: 277
# Episode 159: reward: 208.439, steps: 318
# Episode 160: reward: 236.612, steps: 323
# Episode 161: reward: 175.774, steps: 288
# Episode 162: reward: 233.948, steps: 293
# Episode 163: reward: 222.359, steps: 310
# Episode 164: reward: 218.331, steps: 311
# Episode 165: reward: 214.081, steps: 346
# Episode 166: reward: 170.080, steps: 282
# Episode 167: reward: 50.589, steps: 1000
# Episode 168: reward: 219.835, steps: 313
# Episode 169: reward: 231.451, steps: 326
# Episode 170: reward: 227.307, steps: 328
# Episode 171: reward: 172.130, steps: 293
# Episode 172: reward: 236.303, steps: 312
# Episode 173: reward: 177.867, steps: 346
# Episode 174: reward: 187.567, steps: 311
# Episode 175: reward: 238.502, steps: 335
# Episode 176: reward: 238.041, steps: 323
# Episode 177: reward: 228.171, steps: 304
# Episode 178: reward: 243.039, steps: 311
# Episode 179: reward: 212.562, steps: 343
# Episode 180: reward: 254.954, steps: 255
# Episode 181: reward: 222.762, steps: 317
# Episode 182: reward: 125.708, steps: 431
# Episode 183: reward: 229.375, steps: 296
# Episode 184: reward: 213.065, steps: 322
# Episode 185: reward: 194.229, steps: 298
# Episode 186: reward: 211.217, steps: 282
# Episode 187: reward: 191.425, steps: 338
# Episode 188: reward: 223.032, steps: 297
# Episode 189: reward: 181.959, steps: 399
# Episode 190: reward: 167.311, steps: 375
# Episode 191: reward: 179.565, steps: 278
# Episode 192: reward: 137.233, steps: 805
# Episode 193: reward: 231.239, steps: 334
# Episode 194: reward: 156.760, steps: 298
# Episode 195: reward: 53.708, steps: 1000
# Episode 196: reward: 220.844, steps: 285
# Episode 197: reward: 74.622, steps: 1000
# Episode 198: reward: 235.727, steps: 283
# Episode 199: reward: 225.678, steps: 312
# Episode 200: reward: 213.560, steps: 344
#
# Total rewards =  [199.971, 222.437, 222.27, 245.405, 33.904, 127.211, 190.297, 241.606, 194.045, 204.806, 237.855, 181.652, 180.868, 226.004, 203.962, 193.632, 219.2, 170.339, 138.305, 236.445, 238.679, 146.331, 233.027, 234.126, 181.309, 172.322, 238.372, 225.94, 186.627, 190.323, 121.7, 170.931, 236.337, 191.066, 180.702, 203.158, 224.065, 223.421, 73.037, 194.308, 183.942, 241.257, 240.125, 61.234, 195.11, 260.424, 206.59, 220.82, 238.618, 204.005, 220.326, 220.564, 195.239, 208.598, 244.01, 218.251, 234.109, 219.658, 227.249, 224.236, 258.633, 238.378, 169.841, 218.091, 231.323, 229.5, 228.317, 60.614, 180.037, 205.661, 187.416, 183.613, 210.721, 204.867, 170.455, 217.084, 211.158, 153.314, 234.777, 210.022, 238.519, 176.573, 232.712, 201.12, 186.037, 180.895, 194.254, 188.618, 221.735, 179.872, 239.518, 215.593, 209.493, 212.355, 211.32, 154.645, 228.861, -84.965, 181.534, 212.264, 195.165, 145.209, 188.498, 220.444, 225.663, 221.144, 67.406, 236.691, 199.123, 143.368, 190.786, 177.477, 231.534, 160.175, 231.986, 201.852, 194.116, 206.401, 187.301, 153.505, 187.179, 200.183, 185.241, 191.926, 194.73, 227.294, 194.264, 188.498, 233.377, 168.81, 241.671, 194.438, 235.479, 242.803, 153.55, 234.192, 224.534, 131.476, 227.387, 206.245, 175.087, 58.577, 186.673, 222.055, 233.687, 153.628, 200.247, 177.561, 193.504, 200.802, 236.403, 186.264, 117.859, 194.526, 218.848, 181.622, 228.83, 226.969, 208.439, 236.612, 175.774, 233.948, 222.359, 218.331, 214.081, 170.08, 50.589, 219.835, 231.451, 227.307, 172.13, 236.303, 177.867, 187.567, 238.502, 238.041, 228.171, 243.039, 212.562, 254.954, 222.762, 125.708, 229.375, 213.065, 194.229, 211.217, 191.425, 223.032, 181.959, 167.311, 179.565, 137.233, 231.239, 156.76, 53.708, 220.844, 74.622, 235.727, 225.678, 213.56]
#
# Average total reward =  196.531795

# %% [markdown]
# ### Print the result from the stdout and save results in a csv file

# %%
# Reset stdout
sys.stdout = old_stdout

results_text = mystdout.getvalue()

# Print results text
print("results")
print(results_text)

# Extact a rewards list from the results
total_rewards = list()
for idx, line in enumerate(results_text.split('\n')):
    if idx > 0 and len(line) > 1:
        reward = float(line.split(':')[2].split(',')[0].strip())
        total_rewards.append(reward)

# Print rewards and average reward
print("Total rewards = ", total_rewards)
print("\nAverage total reward = ", np.mean(total_rewards))
        
# Write total rewards to file
f = open("lunarlander_rl_rewards.csv",'w')
wr = csv.writer(f)
for r in total_rewards:
     wr.writerow([r,])
f.close()
# Out:
# results
# Testing for 200 episodes ...
# Episode 1: reward: 199.971, steps: 326
# Episode 2: reward: 222.437, steps: 262
# Episode 3: reward: 222.270, steps: 320
# Episode 4: reward: 245.405, steps: 299
# Episode 5: reward: 33.904, steps: 1000
# Episode 6: reward: 127.211, steps: 418
# Episode 7: reward: 190.297, steps: 320
# Episode 8: reward: 241.606, steps: 280
# Episode 9: reward: 194.045, steps: 331
# Episode 10: reward: 204.806, steps: 280
# Episode 11: reward: 237.855, steps: 321
# Episode 12: reward: 181.652, steps: 375
# Episode 13: reward: 180.868, steps: 352
# Episode 14: reward: 226.004, steps: 326
# Episode 15: reward: 203.962, steps: 309
# Episode 16: reward: 193.632, steps: 341
# Episode 17: reward: 219.200, steps: 324
# Episode 18: reward: 170.339, steps: 296
# Episode 19: reward: 138.305, steps: 464
# Episode 20: reward: 236.445, steps: 281
# Episode 21: reward: 238.679, steps: 333
# Episode 22: reward: 146.331, steps: 383
# Episode 23: reward: 233.027, steps: 318
# Episode 24: reward: 234.126, steps: 306
# Episode 25: reward: 181.309, steps: 335
# Episode 26: reward: 172.322, steps: 308
# Episode 27: reward: 238.372, steps: 271
# Episode 28: reward: 225.940, steps: 355
# Episode 29: reward: 186.627, steps: 274
# Episode 30: reward: 190.323, steps: 373
# Episode 31: reward: 121.700, steps: 368
# Episode 32: reward: 170.931, steps: 329
# Episode 33: reward: 236.337, steps: 293
# Episode 34: reward: 191.066, steps: 269
# Episode 35: reward: 180.702, steps: 298
# Episode 36: reward: 203.158, steps: 321
# Episode 37: reward: 224.065, steps: 297
# Episode 38: reward: 223.421, steps: 271
# Episode 39: reward: 73.037, steps: 1000
# Episode 40: reward: 194.308, steps: 318
# Episode 41: reward: 183.942, steps: 287
# Episode 42: reward: 241.257, steps: 286
# Episode 43: reward: 240.125, steps: 284
# Episode 44: reward: 61.234, steps: 1000
# Episode 45: reward: 195.110, steps: 351
# Episode 46: reward: 260.424, steps: 251
# Episode 47: reward: 206.590, steps: 323
# Episode 48: reward: 220.820, steps: 376
# Episode 49: reward: 238.618, steps: 346
# Episode 50: reward: 204.005, steps: 284
# Episode 51: reward: 220.326, steps: 297
# Episode 52: reward: 220.564, steps: 352
# Episode 53: reward: 195.239, steps: 322
# Episode 54: reward: 208.598, steps: 292
# Episode 55: reward: 244.010, steps: 294
# Episode 56: reward: 218.251, steps: 354
# Episode 57: reward: 234.109, steps: 298
# Episode 58: reward: 219.658, steps: 298
# Episode 59: reward: 227.249, steps: 282
# Episode 60: reward: 224.236, steps: 335
# Episode 61: reward: 258.633, steps: 248
# Episode 62: reward: 238.378, steps: 297
# Episode 63: reward: 169.841, steps: 408
# Episode 64: reward: 218.091, steps: 305
# Episode 65: reward: 231.323, steps: 321
# Episode 66: reward: 229.500, steps: 330
# Episode 67: reward: 228.317, steps: 330
# Episode 68: reward: 60.614, steps: 1000
# Episode 69: reward: 180.037, steps: 362
# Episode 70: reward: 205.661, steps: 313
# Episode 71: reward: 187.416, steps: 316
# Episode 72: reward: 183.613, steps: 283
# Episode 73: reward: 210.721, steps: 310
# Episode 74: reward: 204.867, steps: 338
# Episode 75: reward: 170.455, steps: 352
# Episode 76: reward: 217.084, steps: 293
# Episode 77: reward: 211.158, steps: 284
# Episode 78: reward: 153.314, steps: 318
# Episode 79: reward: 234.777, steps: 323
# Episode 80: reward: 210.022, steps: 297
# Episode 81: reward: 238.519, steps: 297
# Episode 82: reward: 176.573, steps: 341
# Episode 83: reward: 232.712, steps: 303
# Episode 84: reward: 201.120, steps: 337
# Episode 85: reward: 186.037, steps: 334
# Episode 86: reward: 180.895, steps: 291
# Episode 87: reward: 194.254, steps: 332
# Episode 88: reward: 188.618, steps: 306
# Episode 89: reward: 221.735, steps: 319
# Episode 90: reward: 179.872, steps: 413
# Episode 91: reward: 239.518, steps: 290
# Episode 92: reward: 215.593, steps: 322
# Episode 93: reward: 209.493, steps: 348
# Episode 94: reward: 212.355, steps: 304
# Episode 95: reward: 211.320, steps: 287
# Episode 96: reward: 154.645, steps: 377
# Episode 97: reward: 228.861, steps: 306
# Episode 98: reward: -84.965, steps: 249
# Episode 99: reward: 181.534, steps: 386
# Episode 100: reward: 212.264, steps: 292
# Episode 101: reward: 195.165, steps: 266
# Episode 102: reward: 145.209, steps: 405
# Episode 103: reward: 188.498, steps: 298
# Episode 104: reward: 220.444, steps: 301
# Episode 105: reward: 225.663, steps: 287
# Episode 106: reward: 221.144, steps: 301
# Episode 107: reward: 67.406, steps: 1000
# Episode 108: reward: 236.691, steps: 327
# Episode 109: reward: 199.123, steps: 293
# Episode 110: reward: 143.368, steps: 436
# Episode 111: reward: 190.786, steps: 400
# Episode 112: reward: 177.477, steps: 289
# Episode 113: reward: 231.534, steps: 328
# Episode 114: reward: 160.175, steps: 472
# Episode 115: reward: 231.986, steps: 345
# Episode 116: reward: 201.852, steps: 271
# Episode 117: reward: 194.116, steps: 371
# Episode 118: reward: 206.401, steps: 324
# Episode 119: reward: 187.301, steps: 283
# Episode 120: reward: 153.505, steps: 569
# Episode 121: reward: 187.179, steps: 353
# Episode 122: reward: 200.183, steps: 371
# Episode 123: reward: 185.241, steps: 372
# Episode 124: reward: 191.926, steps: 308
# Episode 125: reward: 194.730, steps: 303
# Episode 126: reward: 227.294, steps: 291
# Episode 127: reward: 194.264, steps: 303
# Episode 128: reward: 188.498, steps: 276
# Episode 129: reward: 233.377, steps: 307
# Episode 130: reward: 168.810, steps: 584
# Episode 131: reward: 241.671, steps: 337
# Episode 132: reward: 194.438, steps: 278
# Episode 133: reward: 235.479, steps: 314
# Episode 134: reward: 242.803, steps: 323
# Episode 135: reward: 153.550, steps: 497
# Episode 136: reward: 234.192, steps: 304
# Episode 137: reward: 224.534, steps: 306
# Episode 138: reward: 131.476, steps: 433
# Episode 139: reward: 227.387, steps: 312
# Episode 140: reward: 206.245, steps: 317
# Episode 141: reward: 175.087, steps: 304
# Episode 142: reward: 58.577, steps: 1000
# Episode 143: reward: 186.673, steps: 386
# Episode 144: reward: 222.055, steps: 344
# Episode 145: reward: 233.687, steps: 290
# Episode 146: reward: 153.628, steps: 442
# Episode 147: reward: 200.247, steps: 397
# Episode 148: reward: 177.561, steps: 393
# Episode 149: reward: 193.504, steps: 286
# Episode 150: reward: 200.802, steps: 306
# Episode 151: reward: 236.403, steps: 316
# Episode 152: reward: 186.264, steps: 295
# Episode 153: reward: 117.859, steps: 1000
# Episode 154: reward: 194.526, steps: 303
# Episode 155: reward: 218.848, steps: 293
# Episode 156: reward: 181.622, steps: 318
# Episode 157: reward: 228.830, steps: 291
# Episode 158: reward: 226.969, steps: 277
# Episode 159: reward: 208.439, steps: 318
# Episode 160: reward: 236.612, steps: 323
# Episode 161: reward: 175.774, steps: 288
# Episode 162: reward: 233.948, steps: 293
# Episode 163: reward: 222.359, steps: 310
# Episode 164: reward: 218.331, steps: 311
# Episode 165: reward: 214.081, steps: 346
# Episode 166: reward: 170.080, steps: 282
# Episode 167: reward: 50.589, steps: 1000
# Episode 168: reward: 219.835, steps: 313
# Episode 169: reward: 231.451, steps: 326
# Episode 170: reward: 227.307, steps: 328
# Episode 171: reward: 172.130, steps: 293
# Episode 172: reward: 236.303, steps: 312
# Episode 173: reward: 177.867, steps: 346
# Episode 174: reward: 187.567, steps: 311
# Episode 175: reward: 238.502, steps: 335
# Episode 176: reward: 238.041, steps: 323
# Episode 177: reward: 228.171, steps: 304
# Episode 178: reward: 243.039, steps: 311
# Episode 179: reward: 212.562, steps: 343
# Episode 180: reward: 254.954, steps: 255
# Episode 181: reward: 222.762, steps: 317
# Episode 182: reward: 125.708, steps: 431
# Episode 183: reward: 229.375, steps: 296
# Episode 184: reward: 213.065, steps: 322
# Episode 185: reward: 194.229, steps: 298
# Episode 186: reward: 211.217, steps: 282
# Episode 187: reward: 191.425, steps: 338
# Episode 188: reward: 223.032, steps: 297
# Episode 189: reward: 181.959, steps: 399
# Episode 190: reward: 167.311, steps: 375
# Episode 191: reward: 179.565, steps: 278
# Episode 192: reward: 137.233, steps: 805
# Episode 193: reward: 231.239, steps: 334
# Episode 194: reward: 156.760, steps: 298
# Episode 195: reward: 53.708, steps: 1000
# Episode 196: reward: 220.844, steps: 285
# Episode 197: reward: 74.622, steps: 1000
# Episode 198: reward: 235.727, steps: 283
# Episode 199: reward: 225.678, steps: 312
# Episode 200: reward: 213.560, steps: 344
#
# Total rewards =  [199.971, 222.437, 222.27, 245.405, 33.904, 127.211, 190.297, 241.606, 194.045, 204.806, 237.855, 181.652, 180.868, 226.004, 203.962, 193.632, 219.2, 170.339, 138.305, 236.445, 238.679, 146.331, 233.027, 234.126, 181.309, 172.322, 238.372, 225.94, 186.627, 190.323, 121.7, 170.931, 236.337, 191.066, 180.702, 203.158, 224.065, 223.421, 73.037, 194.308, 183.942, 241.257, 240.125, 61.234, 195.11, 260.424, 206.59, 220.82, 238.618, 204.005, 220.326, 220.564, 195.239, 208.598, 244.01, 218.251, 234.109, 219.658, 227.249, 224.236, 258.633, 238.378, 169.841, 218.091, 231.323, 229.5, 228.317, 60.614, 180.037, 205.661, 187.416, 183.613, 210.721, 204.867, 170.455, 217.084, 211.158, 153.314, 234.777, 210.022, 238.519, 176.573, 232.712, 201.12, 186.037, 180.895, 194.254, 188.618, 221.735, 179.872, 239.518, 215.593, 209.493, 212.355, 211.32, 154.645, 228.861, -84.965, 181.534, 212.264, 195.165, 145.209, 188.498, 220.444, 225.663, 221.144, 67.406, 236.691, 199.123, 143.368, 190.786, 177.477, 231.534, 160.175, 231.986, 201.852, 194.116, 206.401, 187.301, 153.505, 187.179, 200.183, 185.241, 191.926, 194.73, 227.294, 194.264, 188.498, 233.377, 168.81, 241.671, 194.438, 235.479, 242.803, 153.55, 234.192, 224.534, 131.476, 227.387, 206.245, 175.087, 58.577, 186.673, 222.055, 233.687, 153.628, 200.247, 177.561, 193.504, 200.802, 236.403, 186.264, 117.859, 194.526, 218.848, 181.622, 228.83, 226.969, 208.439, 236.612, 175.774, 233.948, 222.359, 218.331, 214.081, 170.08, 50.589, 219.835, 231.451, 227.307, 172.13, 236.303, 177.867, 187.567, 238.502, 238.041, 228.171, 243.039, 212.562, 254.954, 222.762, 125.708, 229.375, 213.065, 194.229, 211.217, 191.425, 223.032, 181.959, 167.311, 179.565, 137.233, 231.239, 156.76, 53.708, 220.844, 74.622, 235.727, 225.678, 213.56]
#
# Average total reward =  196.531795

# %% [markdown]
# Thus, our RL model architecture gives really good overall rewards. Average reward is 196.53 whereas the maximum is 251.4.
#
# Only one test episode resulted in a negative reward, so the trained model performs really well.
# The time taken to train and fit the model was around 4-5 hours. This is quite exorbitant time taken in comparison to ANN and CNN models.
